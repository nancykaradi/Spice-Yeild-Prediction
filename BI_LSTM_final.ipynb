# %% [markdown]
# # **Bi LSTM Dry Ginger**

# %%
# !pip install scikit-learn==0.24

# %%
import numpy as np
import pandas as pd
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import sklearn.preprocessing as pre
from keras.models import Sequential
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
# importing data
data_dg = pd.read_csv("/content/dry ginger 2008-2020.csv")

# %%
data_dg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DISTRICT                181 non-null    object
#  1   YEAR                    181 non-null    int64
#  2   AREA                    181 non-null    int64
#  3   PRODUCTION              181 non-null    int64
#  4   AVERAGE RAINFALL        181 non-null    float64
#  5   MINIMUM TEMPERATURE     181 non-null    float64
#  6   MAXIMUM TEMPERATURE     181 non-null    float64
#  7   AVERAGE TEMPERATURE     181 non-null    float64
#  8   RELATIVE SOIL MOISTURE  181 non-null    float64
#  9   AVERAGE WINDSPEED       181 non-null    float64
#  10  pH                      181 non-null    float64
#  11  YIELD                   181 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 17.1+ KB

# %%
le=pre.LabelEncoder()
cat_df_dg=data_dg.select_dtypes(exclude=[float,int])
for x in cat_df_dg.columns:
    data_dg[x]=le.fit_transform(data_dg[x])


data_dg.head()
# Out:
#    DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED    pH  YIELD
# 0         0  2008   161  ...               8.29  6.27   2.19
# 1         0  2009    66  ...               8.52  6.07   2.47
# 2         0  2010    87  ...               7.88  5.62   3.02
# 3         0  2011    94  ...               7.89  5.56   1.83
# 4         0  2012   125  ...               8.19  6.04   1.76
#
# [5 rows x 12 columns]

# %%
scaled_df = pre.minmax_scale(data_dg.values)

# %%
df_Norm = pd.DataFrame(data = scaled_df, columns = data_dg.columns.to_list())

# %%
df_Norm.head()
# Out:
#    DISTRICT      YEAR      AREA  ...  AVERAGE WINDSPEED    pH     YIELD
# 0       0.0  0.000000  0.019857  ...           0.461735  0.72  0.109817
# 1       0.0  0.083333  0.006757  ...           0.491071  0.52  0.156406
# 2       0.0  0.166667  0.009653  ...           0.409439  0.07  0.247920
# 3       0.0  0.250000  0.010618  ...           0.410714  0.01  0.049917
# 4       0.0  0.333333  0.014892  ...           0.448980  0.49  0.038270
#
# [5 rows x 12 columns]

# %%
X=df_Norm.drop(['YIELD'], axis=1)
Y=df_Norm["YIELD"]
X
# Out:
#      DISTRICT      YEAR  ...  AVERAGE WINDSPEED    pH
# 0    0.000000  0.000000  ...           0.461735  0.72
# 1    0.000000  0.083333  ...           0.491071  0.52
# 2    0.000000  0.166667  ...           0.409439  0.07
# 3    0.000000  0.250000  ...           0.410714  0.01
# 4    0.000000  0.333333  ...           0.448980  0.49
# ..        ...       ...  ...                ...   ...
# 176  0.307692  0.750000  ...           0.608418  0.00
# 177  0.307692  0.833333  ...           0.698980  0.96
# 178  0.307692  0.916667  ...           0.661990  0.92
# 179  0.307692  1.000000  ...           0.656888  0.60
# 180  0.307692  0.000000  ...           0.600765  0.67
#
# [181 rows x 11 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,train_size=0.7,random_state=21311)

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (126, 1, 11) (126,) (55, 1, 11) (55,)

# %%
# The LSTM architecture
regressorBilstm = Sequential()
# First LSTM layer with Dropout regularisation
regressorBilstm.add(LSTM( units=50, dropout = 0.10, return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2])))
regressorBilstm.add(Dropout(0.2))
# Second LSTM layer
regressorBilstm.add(LSTM(units=50, dropout = 0.10, return_sequences=True))
regressorBilstm.add(Dropout(0.2))
# Third LSTM layer
regressorBilstm.add(LSTM(units=50, dropout = 0.10, return_sequences=True))
regressorBilstm.add(Dropout(0.2))
# Fourth LSTM layer
regressorBilstm.add(LSTM( units=50, dropout = 0.10))
regressorBilstm.add(Dropout(0.2))
# The output layer
regressorBilstm.add(Dense(units=1))

# Compiling the LSTM
regressorBilstm.compile(optimizer='adam',loss='mean_squared_error')
# Fitting to the training set
regressorBilstm.summary()
history=regressorBilstm.fit(X_train,y_train,validation_data=(X_test, y_test),epochs=150,shuffle=False)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 1, 50)             12400
#
#  dropout_8 (Dropout)         (None, 1, 50)             0
#
#  lstm_9 (LSTM)               (None, 1, 50)             20200
#
#  dropout_9 (Dropout)         (None, 1, 50)             0
#
#  lstm_10 (LSTM)              (None, 1, 50)             20200
#
#  dropout_10 (Dropout)        (None, 1, 50)             0
#
#  lstm_11 (LSTM)              (None, 50)                20200
#
#  dropout_11 (Dropout)        (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 73,051
# Trainable params: 73,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 4/4 [==============================] - 9s 690ms/step - loss: 0.1024 - val_loss: 0.0872
# Epoch 2/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0939 - val_loss: 0.0792
# Epoch 3/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0849 - val_loss: 0.0707
# Epoch 4/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0750 - val_loss: 0.0614
# Epoch 5/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0645 - val_loss: 0.0512
# Epoch 6/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0531 - val_loss: 0.0404
# Epoch 7/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0397 - val_loss: 0.0305
# Epoch 8/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0297 - val_loss: 0.0254
# Epoch 9/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0258 - val_loss: 0.0282
# Epoch 10/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0291 - val_loss: 0.0286
# Epoch 11/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0296 - val_loss: 0.0259
# Epoch 12/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0265 - val_loss: 0.0254
# Epoch 13/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0256 - val_loss: 0.0255
# Epoch 14/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0246 - val_loss: 0.0254
# Epoch 15/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0249 - val_loss: 0.0252
# Epoch 16/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0255 - val_loss: 0.0251
# Epoch 17/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0255 - val_loss: 0.0251
# Epoch 18/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0256 - val_loss: 0.0251
# Epoch 19/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0237 - val_loss: 0.0250
# Epoch 20/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0250 - val_loss: 0.0248
# Epoch 21/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0235 - val_loss: 0.0246
# Epoch 22/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0241 - val_loss: 0.0244
# Epoch 23/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0239 - val_loss: 0.0242
# Epoch 24/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0223 - val_loss: 0.0240
# Epoch 25/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0217 - val_loss: 0.0238
# Epoch 26/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0236 - val_loss: 0.0236
# Epoch 27/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0229 - val_loss: 0.0234
# Epoch 28/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0210 - val_loss: 0.0231
# Epoch 29/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 30/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0202 - val_loss: 0.0226
# Epoch 31/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0221 - val_loss: 0.0223
# Epoch 32/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0236 - val_loss: 0.0220
# Epoch 33/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0210 - val_loss: 0.0217
# Epoch 34/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0237 - val_loss: 0.0215
# Epoch 35/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0195 - val_loss: 0.0212
# Epoch 36/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0206 - val_loss: 0.0212
# Epoch 37/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0200 - val_loss: 0.0212
# Epoch 38/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 39/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0196 - val_loss: 0.0211
# Epoch 40/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0194 - val_loss: 0.0210
# Epoch 41/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0183 - val_loss: 0.0209
# Epoch 42/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0182 - val_loss: 0.0209
# Epoch 43/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0167 - val_loss: 0.0209
# Epoch 44/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0185 - val_loss: 0.0207
# Epoch 45/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0184 - val_loss: 0.0206
# Epoch 46/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0210 - val_loss: 0.0210
# Epoch 47/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0195 - val_loss: 0.0218
# Epoch 48/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0196 - val_loss: 0.0217
# Epoch 49/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0179 - val_loss: 0.0213
# Epoch 50/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0178 - val_loss: 0.0213
# Epoch 51/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0200 - val_loss: 0.0213
# Epoch 52/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0200 - val_loss: 0.0210
# Epoch 53/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0181 - val_loss: 0.0211
# Epoch 54/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0163 - val_loss: 0.0210
# Epoch 55/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0191 - val_loss: 0.0207
# Epoch 56/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0205
# Epoch 57/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0179 - val_loss: 0.0204
# Epoch 58/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0200 - val_loss: 0.0206
# Epoch 59/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0180 - val_loss: 0.0208
# Epoch 60/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0177 - val_loss: 0.0207
# Epoch 61/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0198 - val_loss: 0.0205
# Epoch 62/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0165 - val_loss: 0.0205
# Epoch 63/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0140 - val_loss: 0.0204
# Epoch 64/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0171 - val_loss: 0.0203
# Epoch 65/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0149 - val_loss: 0.0201
# Epoch 66/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0165 - val_loss: 0.0200
# Epoch 67/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0148 - val_loss: 0.0198
# Epoch 68/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0191 - val_loss: 0.0199
# Epoch 69/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0186 - val_loss: 0.0200
# Epoch 70/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0157 - val_loss: 0.0200
# Epoch 71/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0182 - val_loss: 0.0200
# Epoch 72/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0178 - val_loss: 0.0201
# Epoch 73/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0204 - val_loss: 0.0204
# Epoch 74/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0171 - val_loss: 0.0205
# Epoch 75/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0185 - val_loss: 0.0204
# Epoch 76/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0159 - val_loss: 0.0204
# Epoch 77/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0170 - val_loss: 0.0203
# Epoch 78/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0180 - val_loss: 0.0203
# Epoch 79/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0162 - val_loss: 0.0203
# Epoch 80/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0202
# Epoch 81/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0201
# Epoch 82/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0152 - val_loss: 0.0200
# Epoch 83/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0147 - val_loss: 0.0199
# Epoch 84/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0198
# Epoch 85/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0156 - val_loss: 0.0197
# Epoch 86/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0165 - val_loss: 0.0197
# Epoch 87/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0152 - val_loss: 0.0198
# Epoch 88/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0168 - val_loss: 0.0200
# Epoch 89/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0198
# Epoch 90/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0179 - val_loss: 0.0198
# Epoch 91/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0160 - val_loss: 0.0199
# Epoch 92/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0160 - val_loss: 0.0199
# Epoch 93/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0168 - val_loss: 0.0198
# Epoch 94/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0197
# Epoch 95/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0197
# Epoch 96/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0160 - val_loss: 0.0198
# Epoch 97/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0174 - val_loss: 0.0198
# Epoch 98/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 0.0196
# Epoch 99/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0155 - val_loss: 0.0196
# Epoch 100/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.0196
# Epoch 101/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0175 - val_loss: 0.0194
# Epoch 102/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0180 - val_loss: 0.0195
# Epoch 103/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0149 - val_loss: 0.0195
# Epoch 104/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0153 - val_loss: 0.0195
# Epoch 105/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0174 - val_loss: 0.0194
# Epoch 106/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0155 - val_loss: 0.0194
# Epoch 107/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0168 - val_loss: 0.0192
# Epoch 108/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0141 - val_loss: 0.0192
# Epoch 109/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0148 - val_loss: 0.0191
# Epoch 110/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0153 - val_loss: 0.0188
# Epoch 111/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0164 - val_loss: 0.0187
# Epoch 112/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0140 - val_loss: 0.0187
# Epoch 113/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0155 - val_loss: 0.0186
# Epoch 114/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 115/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 116/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0163 - val_loss: 0.0186
# Epoch 117/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0187
# Epoch 118/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0129 - val_loss: 0.0187
# Epoch 119/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0161 - val_loss: 0.0186
# Epoch 120/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0141 - val_loss: 0.0185
# Epoch 121/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0176 - val_loss: 0.0184
# Epoch 122/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0129 - val_loss: 0.0184
# Epoch 123/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0160 - val_loss: 0.0182
# Epoch 124/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0121 - val_loss: 0.0182
# Epoch 125/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0176 - val_loss: 0.0181
# Epoch 126/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0154 - val_loss: 0.0182
# Epoch 127/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0125 - val_loss: 0.0183
# Epoch 128/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0144 - val_loss: 0.0183
# Epoch 129/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0154 - val_loss: 0.0182
# Epoch 130/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0119 - val_loss: 0.0181
# Epoch 131/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0143 - val_loss: 0.0179
# Epoch 132/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0147 - val_loss: 0.0179
# Epoch 133/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0149 - val_loss: 0.0180
# Epoch 134/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0180 - val_loss: 0.0179
# Epoch 135/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0145 - val_loss: 0.0179
# Epoch 136/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0152 - val_loss: 0.0179
# Epoch 137/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0179 - val_loss: 0.0179
# Epoch 138/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0165 - val_loss: 0.0180
# Epoch 139/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0140 - val_loss: 0.0180
# Epoch 140/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0131 - val_loss: 0.0179
# Epoch 141/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0143 - val_loss: 0.0178
# Epoch 142/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0133 - val_loss: 0.0176
# Epoch 143/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0175
# Epoch 144/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0138 - val_loss: 0.0175
# Epoch 145/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0173 - val_loss: 0.0174
# Epoch 146/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0137 - val_loss: 0.0174
# Epoch 147/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0130 - val_loss: 0.0174
# Epoch 148/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0148 - val_loss: 0.0174
# Epoch 149/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 0.0174
# Epoch 150/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0134 - val_loss: 0.0173

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make predictions
trainPredict = regressorBilstm.predict(X_train)
testPredict = regressorBilstm.predict(X_test)

# %%
plt.title('Train Dataset - Predicted v/s Actual')
plt.plot(trainPredict , label='Predicted')
plt.plot(y_train, label='Actual')
plt.legend()
plt.show()

# %%
plt.title('Test Dataset - Predicted v/s Actual')
plt.plot(testPredict , label='Predicted')
plt.plot(y_test, label='Actual')
plt.legend()
plt.show()

# %%
#Mean Absolute Error
mae_train = mean_absolute_error(y_train, trainPredict)
mae_test = mean_absolute_error(y_test, testPredict)
print('MAE Train: %.3f'% (mae_train))
print('MAE Test: %.3f'% (mae_test))
#Root Mean Squared Error
rmse_train = mean_squared_error(y_train, trainPredict, squared=False)
rmse_test = mean_squared_error(y_test, testPredict, squared=False)
print('RMSE Train: %.3f'% (rmse_train))
print('RMSE Test: %.3f'% (rmse_test))
#Mean Absolute Percentage Error
mp_train = mean_absolute_percentage_error(trainPredict,y_train)
mp_test = mean_absolute_percentage_error(testPredict,y_test)
print('MAPE Train: %.3f'% (mp_train))
print('MAPE Test: %.3f'% (mp_test))
# Out:
# MAE Train: 0.081
# MAE Test: 0.098
# RMSE Train: 0.110
# RMSE Test: 0.132
# MAPE Train: 0.299
# MAPE Test: 0.365

# %% [markdown]
# # **Black Pepper**

# %%
data_bp = pd.read_csv("/content/black pepper 2008-2020.csv")
data_bp.head()
# Out:
#     DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED   pH  YIELD
# 0  Alappuzha  2008  2028  ...               8.29  6.6   0.13
# 1  Alappuzha  2009  1943  ...               8.52  6.2   0.12
# 2  Alappuzha  2010  2134  ...               7.88  6.0   0.14
# 3  Alappuzha  2011  1940  ...               7.89  5.9   0.09
# 4  Alappuzha  2012  1997  ...               8.19  6.0   0.08
#
# [5 rows x 12 columns]

# %%
le=pre.LabelEncoder()
cat_df_bp=data_bp.select_dtypes(exclude=[float,int])
for x in cat_df_bp.columns:
    data_bp[x]=le.fit_transform(data_bp[x])


data_bp.head()
# Out:
#    DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED   pH  YIELD
# 0         0  2008  2028  ...               8.29  6.6   0.13
# 1         0  2009  1943  ...               8.52  6.2   0.12
# 2         0  2010  2134  ...               7.88  6.0   0.14
# 3         0  2011  1940  ...               7.89  5.9   0.09
# 4         0  2012  1997  ...               8.19  6.0   0.08
#
# [5 rows x 12 columns]

# %%
scaled_df_bp = pre.minmax_scale(data_bp.values)
df_Norm_bp = pd.DataFrame(data = scaled_df_bp, columns = data_bp.columns.to_list())
df_Norm_bp.head()
# Out:
#    DISTRICT      YEAR      AREA  ...  AVERAGE WINDSPEED        pH     YIELD
# 0       0.0  0.000000  0.015055  ...           0.461735  1.000000  0.092593
# 1       0.0  0.083333  0.014073  ...           0.491071  0.666667  0.074074
# 2       0.0  0.166667  0.016280  ...           0.409439  0.500000  0.111111
# 3       0.0  0.250000  0.014038  ...           0.410714  0.416667  0.018519
# 4       0.0  0.333333  0.014697  ...           0.448980  0.500000  0.000000
#
# [5 rows x 12 columns]

# %%
X_bp=df_Norm_bp.drop(['YIELD'], axis=1)
Y_bp=df_Norm_bp["YIELD"]

# %%
X_train_bp,X_test_bp,y_train_bp,y_test_bp=train_test_split(X_bp,Y_bp,train_size=0.7,random_state=21311)

# %%
X_train_bp, y_train_bp = np.array(X_train_bp), np.array(y_train_bp)
X_test_bp, y_test_bp = np.array(X_test_bp), np.array(y_test_bp)
X_train_bp = X_train_bp.reshape((X_train_bp.shape[0], 1, X_train_bp.shape[1]))
X_test_bp = X_test_bp.reshape((X_test_bp.shape[0], 1, X_test_bp.shape[1]))
print(X_train_bp.shape, y_train_bp.shape, X_test_bp.shape, y_test_bp.shape)
# Out:
# (118, 1, 11) (118,) (51, 1, 11) (51,)

# %%
# The LSTM architecture
regressorBilstm = Sequential()
# First LSTM layer with Dropout regularisation
regressorBilstm.add(LSTM( units=50, dropout = 0.10, return_sequences=True, input_shape = (X_train_bp.shape[1], X_train_bp.shape[2])))
regressorBilstm.add(Dropout(0.2))
# Second LSTM layer
regressorBilstm.add(LSTM(units=50, dropout = 0.10, return_sequences=True))
regressorBilstm.add(Dropout(0.2))
# Third LSTM layer
regressorBilstm.add(LSTM(units=50, dropout = 0.10, return_sequences=True))
regressorBilstm.add(Dropout(0.2))
# Fourth LSTM layer
regressorBilstm.add(LSTM( units=50, dropout = 0.10))
regressorBilstm.add(Dropout(0.2))
# The output layer
regressorBilstm.add(Dense(units=1))

# Compiling the LSTM
regressorBilstm.compile(optimizer='adam',loss='mean_squared_error')
# Fitting to the training set
regressorBilstm.summary()
history_bp=regressorBilstm.fit(X_train_bp,y_train_bp,validation_data=(X_test_bp, y_test_bp),epochs=150,shuffle=False)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 1, 50)             12400
#
#  dropout_12 (Dropout)        (None, 1, 50)             0
#
#  lstm_13 (LSTM)              (None, 1, 50)             20200
#
#  dropout_13 (Dropout)        (None, 1, 50)             0
#
#  lstm_14 (LSTM)              (None, 1, 50)             20200
#
#  dropout_14 (Dropout)        (None, 1, 50)             0
#
#  lstm_15 (LSTM)              (None, 50)                20200
#
#  dropout_15 (Dropout)        (None, 50)                0
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 73,051
# Trainable params: 73,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 4/4 [==============================] - 9s 794ms/step - loss: 0.0920 - val_loss: 0.1164
# Epoch 2/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0839 - val_loss: 0.1074
# Epoch 3/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0759 - val_loss: 0.0976
# Epoch 4/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0667 - val_loss: 0.0870
# Epoch 5/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0578 - val_loss: 0.0755
# Epoch 6/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0469 - val_loss: 0.0637
# Epoch 7/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0377 - val_loss: 0.0539
# Epoch 8/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0341 - val_loss: 0.0498
# Epoch 9/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0341 - val_loss: 0.0496
# Epoch 10/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0361 - val_loss: 0.0489
# Epoch 11/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0337 - val_loss: 0.0492
# Epoch 12/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0323 - val_loss: 0.0502
# Epoch 13/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0319 - val_loss: 0.0504
# Epoch 14/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0309 - val_loss: 0.0496
# Epoch 15/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0310 - val_loss: 0.0481
# Epoch 16/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0301 - val_loss: 0.0468
# Epoch 17/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0308 - val_loss: 0.0456
# Epoch 18/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0298 - val_loss: 0.0448
# Epoch 19/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0293 - val_loss: 0.0441
# Epoch 20/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0302 - val_loss: 0.0436
# Epoch 21/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0275 - val_loss: 0.0427
# Epoch 22/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0264 - val_loss: 0.0414
# Epoch 23/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0248 - val_loss: 0.0396
# Epoch 24/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0263 - val_loss: 0.0377
# Epoch 25/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0236 - val_loss: 0.0362
# Epoch 26/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0259 - val_loss: 0.0344
# Epoch 27/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0236 - val_loss: 0.0327
# Epoch 28/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0260 - val_loss: 0.0320
# Epoch 29/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0208 - val_loss: 0.0303
# Epoch 30/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0198 - val_loss: 0.0286
# Epoch 31/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0198 - val_loss: 0.0275
# Epoch 32/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0246 - val_loss: 0.0275
# Epoch 33/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0212 - val_loss: 0.0266
# Epoch 34/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0207 - val_loss: 0.0259
# Epoch 35/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0235 - val_loss: 0.0258
# Epoch 36/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0210 - val_loss: 0.0269
# Epoch 37/150
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0207 - val_loss: 0.0272
# Epoch 38/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0208 - val_loss: 0.0274
# Epoch 39/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0221 - val_loss: 0.0266
# Epoch 40/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0223 - val_loss: 0.0262
# Epoch 41/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0184 - val_loss: 0.0269
# Epoch 42/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0195 - val_loss: 0.0281
# Epoch 43/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0207 - val_loss: 0.0282
# Epoch 44/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0211 - val_loss: 0.0267
# Epoch 45/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0235 - val_loss: 0.0258
# Epoch 46/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0208 - val_loss: 0.0257
# Epoch 47/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0193 - val_loss: 0.0262
# Epoch 48/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0190 - val_loss: 0.0267
# Epoch 49/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0252 - val_loss: 0.0263
# Epoch 50/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0172 - val_loss: 0.0251
# Epoch 51/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0206 - val_loss: 0.0244
# Epoch 52/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0191 - val_loss: 0.0251
# Epoch 53/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0186 - val_loss: 0.0262
# Epoch 54/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0199 - val_loss: 0.0266
# Epoch 55/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0266
# Epoch 56/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0187 - val_loss: 0.0254
# Epoch 57/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0189 - val_loss: 0.0248
# Epoch 58/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0196 - val_loss: 0.0250
# Epoch 59/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0256
# Epoch 60/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0201 - val_loss: 0.0265
# Epoch 61/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0180 - val_loss: 0.0260
# Epoch 62/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0182 - val_loss: 0.0257
# Epoch 63/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0223 - val_loss: 0.0264
# Epoch 64/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0185 - val_loss: 0.0257
# Epoch 65/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0198 - val_loss: 0.0247
# Epoch 66/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0233 - val_loss: 0.0248
# Epoch 67/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0212 - val_loss: 0.0255
# Epoch 68/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0257
# Epoch 69/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0192 - val_loss: 0.0247
# Epoch 70/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0196 - val_loss: 0.0239
# Epoch 71/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0174 - val_loss: 0.0239
# Epoch 72/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0169 - val_loss: 0.0242
# Epoch 73/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0167 - val_loss: 0.0234
# Epoch 74/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0201 - val_loss: 0.0227
# Epoch 75/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0181 - val_loss: 0.0229
# Epoch 76/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0179 - val_loss: 0.0236
# Epoch 77/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0188 - val_loss: 0.0248
# Epoch 78/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0152 - val_loss: 0.0243
# Epoch 79/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0170 - val_loss: 0.0236
# Epoch 80/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0182 - val_loss: 0.0235
# Epoch 81/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0183 - val_loss: 0.0238
# Epoch 82/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0160 - val_loss: 0.0243
# Epoch 83/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0194 - val_loss: 0.0245
# Epoch 84/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0162 - val_loss: 0.0243
# Epoch 85/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0150 - val_loss: 0.0235
# Epoch 86/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0196 - val_loss: 0.0235
# Epoch 87/150
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0163 - val_loss: 0.0227
# Epoch 88/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0165 - val_loss: 0.0223
# Epoch 89/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0196 - val_loss: 0.0232
# Epoch 90/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0256
# Epoch 91/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0156 - val_loss: 0.0248
# Epoch 92/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0166 - val_loss: 0.0235
# Epoch 93/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0221 - val_loss: 0.0237
# Epoch 94/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0177 - val_loss: 0.0239
# Epoch 95/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0185 - val_loss: 0.0246
# Epoch 96/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0168 - val_loss: 0.0248
# Epoch 97/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 0.0243
# Epoch 98/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0183 - val_loss: 0.0235
# Epoch 99/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0183 - val_loss: 0.0233
# Epoch 100/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0135 - val_loss: 0.0233
# Epoch 101/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0171 - val_loss: 0.0232
# Epoch 102/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0174 - val_loss: 0.0226
# Epoch 103/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0192 - val_loss: 0.0230
# Epoch 104/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0165 - val_loss: 0.0236
# Epoch 105/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0167 - val_loss: 0.0235
# Epoch 106/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0161 - val_loss: 0.0227
# Epoch 107/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0174 - val_loss: 0.0223
# Epoch 108/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0209 - val_loss: 0.0228
# Epoch 109/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0171 - val_loss: 0.0233
# Epoch 110/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0238
# Epoch 111/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0192 - val_loss: 0.0241
# Epoch 112/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0177 - val_loss: 0.0239
# Epoch 113/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0157 - val_loss: 0.0235
# Epoch 114/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0169 - val_loss: 0.0232
# Epoch 115/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0169 - val_loss: 0.0234
# Epoch 116/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0237
# Epoch 117/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0173 - val_loss: 0.0235
# Epoch 118/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0145 - val_loss: 0.0229
# Epoch 119/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0190 - val_loss: 0.0223
# Epoch 120/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0154 - val_loss: 0.0221
# Epoch 121/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0172 - val_loss: 0.0233
# Epoch 122/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0181 - val_loss: 0.0231
# Epoch 123/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0155 - val_loss: 0.0227
# Epoch 124/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0159 - val_loss: 0.0230
# Epoch 125/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0235
# Epoch 126/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0156 - val_loss: 0.0240
# Epoch 127/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0237
# Epoch 128/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0234
# Epoch 129/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0166 - val_loss: 0.0235
# Epoch 130/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0158 - val_loss: 0.0239
# Epoch 131/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0179 - val_loss: 0.0237
# Epoch 132/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0144 - val_loss: 0.0232
# Epoch 133/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0174 - val_loss: 0.0229
# Epoch 134/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0184 - val_loss: 0.0238
# Epoch 135/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0153 - val_loss: 0.0244
# Epoch 136/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0237
# Epoch 137/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0166 - val_loss: 0.0235
# Epoch 138/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0160 - val_loss: 0.0241
# Epoch 139/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0185 - val_loss: 0.0241
# Epoch 140/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0169 - val_loss: 0.0233
# Epoch 141/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0140 - val_loss: 0.0224
# Epoch 142/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0170 - val_loss: 0.0223
# Epoch 143/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0186 - val_loss: 0.0229
# Epoch 144/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0170 - val_loss: 0.0234
# Epoch 145/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0177 - val_loss: 0.0231
# Epoch 146/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0230
# Epoch 147/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0157 - val_loss: 0.0229
# Epoch 148/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0186 - val_loss: 0.0224
# Epoch 149/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0151 - val_loss: 0.0219
# Epoch 150/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0175 - val_loss: 0.0217

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history_bp.history['loss'], label='train')
plt.plot(history_bp.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make predictions
trainPredict_bp = regressorBilstm.predict(X_train_bp)
testPredict_bp = regressorBilstm.predict(X_test_bp)

# %%
plt.title('Train Dataset - Predicted v/s Actual')
plt.plot(trainPredict_bp , label='Predicted')
plt.plot(y_train_bp, label='Actual')
plt.legend()
plt.show()

# %%
plt.title('Test Dataset - Predicted v/s Actual')
plt.plot(testPredict_bp , label='Predicted')
plt.plot(y_test_bp, label='Actual')
plt.legend()
plt.show()

# %%
#Mean Absolute Error
mae_train_bp = mean_absolute_error(y_train_bp, trainPredict_bp)
mae_test_bp = mean_absolute_error(y_test_bp, testPredict_bp)
print('MAE Train: %.3f'% (mae_train_bp))
print('MAE Test: %.3f'% (mae_test_bp))
#Root Mean Squared Error
rmse_train_bp = mean_squared_error(y_train_bp, trainPredict_bp, squared=False)
rmse_test_bp = mean_squared_error(y_test_bp, testPredict_bp, squared=False)
print('RMSE Train: %.3f'% (rmse_train_bp))
print('RMSE Test: %.3f'% (rmse_test_bp))
#Mean Absolute Percentage Error
mp_train = mean_absolute_percentage_error(trainPredict,y_train)
mp_test = mean_absolute_percentage_error(testPredict,y_test)
print('MAPE Train: %.3f'% (mp_train))
print('MAPE Test: %.3f'% (mp_test))
# Out:
# MAE Train: 0.091
# MAE Test: 0.107
# RMSE Train: 0.114
# RMSE Test: 0.147
# MAPE Train: 0.299
# MAPE Test: 0.365

# %% [markdown]
# # **Turmeric**

# %%
data_tm = pd.read_csv("/content/turmeric 2008-2020.csv")
data_tm.head()
# Out:
#     DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED    pH  YIELD
# 0  Alappuzha  2008    11  ...               8.29  6.28   1.18
# 1  Alappuzha  2009    20  ...               8.52  4.89   1.05
# 2  Alappuzha  2010    15  ...               7.88  5.38   1.33
# 3  Alappuzha  2011    12  ...               7.89  5.46   1.75
# 4  Alappuzha  2012    11  ...               8.19  5.64   1.09
#
# [5 rows x 12 columns]

# %%
le=pre.LabelEncoder()
cat_df_tm=data_tm.select_dtypes(exclude=[float,int])
for x in cat_df_tm.columns:
    data_tm[x]=le.fit_transform(data_tm[x])


data_tm.head()
# Out:
#    DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED    pH  YIELD
# 0         0  2008    11  ...               8.29  6.28   1.18
# 1         0  2009    20  ...               8.52  4.89   1.05
# 2         0  2010    15  ...               7.88  5.38   1.33
# 3         0  2011    12  ...               7.89  5.46   1.75
# 4         0  2012    11  ...               8.19  5.64   1.09
#
# [5 rows x 12 columns]

# %%
scaled_df_tm = pre.minmax_scale(data_tm.values)
df_Norm_tm = pd.DataFrame(data = scaled_df_tm, columns = data_tm.columns.to_list())
df_Norm_tm.head()
# Out:
#    DISTRICT      YEAR      AREA  ...  AVERAGE WINDSPEED        pH     YIELD
# 0       0.0  0.000000  0.003148  ...           0.461735  0.515254  0.106007
# 1       0.0  0.083333  0.012592  ...           0.491071  0.044068  0.060071
# 2       0.0  0.166667  0.007345  ...           0.409439  0.210169  0.159011
# 3       0.0  0.250000  0.004197  ...           0.410714  0.237288  0.307420
# 4       0.0  0.333333  0.003148  ...           0.448980  0.298305  0.074205
#
# [5 rows x 12 columns]

# %%
X_tm=df_Norm_tm.drop(['YIELD'], axis=1)
Y_tm=df_Norm_tm["YIELD"]

# %%
X_train_tm,X_test_tm,y_train_tm,y_test_tm=train_test_split(X_tm,Y_tm,train_size=0.7,random_state=21311)

# %%
X_train_tm, y_train_tm = np.array(X_train_tm), np.array(y_train_tm)
X_test_tm, y_test_tm = np.array(X_test_tm), np.array(y_test_tm)
X_train_tm = X_train_tm.reshape((X_train_tm.shape[0], 1, X_train_tm.shape[1]))
X_test_tm = X_test_tm.reshape((X_test_tm.shape[0], 1, X_test_tm.shape[1]))
print(X_train_tm.shape, y_train_tm.shape, X_test_tm.shape, y_test_tm.shape)
# Out:
# (126, 1, 11) (126,) (55, 1, 11) (55,)

# %%
# The LSTM architecture
regressorBilstm = Sequential()
# First LSTM layer with Dropout regularisation
regressorBilstm.add(LSTM( units=50, dropout = 0.10, return_sequences=True, input_shape = (X_train_bp.shape[1], X_train_bp.shape[2])))
regressorBilstm.add(Dropout(0.2))
# Second LSTM layer
regressorBilstm.add(LSTM(units=50, dropout = 0.10, return_sequences=True))
regressorBilstm.add(Dropout(0.2))
# Third LSTM layer
regressorBilstm.add(LSTM(units=50, dropout = 0.10, return_sequences=True))
regressorBilstm.add(Dropout(0.2))
# Fourth LSTM layer
regressorBilstm.add(LSTM( units=50, dropout = 0.10))
regressorBilstm.add(Dropout(0.2))
# The output layer
regressorBilstm.add(Dense(units=1))

# Compiling the LSTM
regressorBilstm.compile(optimizer='adam',loss='mean_squared_error')
# Fitting to the training set
regressorBilstm.summary()
history_bp=regressorBilstm.fit(X_train_bp,y_train_bp,validation_data=(X_test_bp, y_test_bp),epochs=150,shuffle=False)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 1, 50)             12400
#
#  dropout_20 (Dropout)        (None, 1, 50)             0
#
#  lstm_21 (LSTM)              (None, 1, 50)             20200
#
#  dropout_21 (Dropout)        (None, 1, 50)             0
#
#  lstm_22 (LSTM)              (None, 1, 50)             20200
#
#  dropout_22 (Dropout)        (None, 1, 50)             0
#
#  lstm_23 (LSTM)              (None, 50)                20200
#
#  dropout_23 (Dropout)        (None, 50)                0
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 73,051
# Trainable params: 73,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 4/4 [==============================] - 9s 547ms/step - loss: 0.0924 - val_loss: 0.1172
# Epoch 2/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0848 - val_loss: 0.1088
# Epoch 3/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0769 - val_loss: 0.0999
# Epoch 4/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0690 - val_loss: 0.0903
# Epoch 5/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0602 - val_loss: 0.0800
# Epoch 6/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0519 - val_loss: 0.0691
# Epoch 7/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0417 - val_loss: 0.0589
# Epoch 8/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0353 - val_loss: 0.0523
# Epoch 9/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0342 - val_loss: 0.0514
# Epoch 10/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0359 - val_loss: 0.0509
# Epoch 11/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0343 - val_loss: 0.0505
# Epoch 12/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0326 - val_loss: 0.0511
# Epoch 13/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0310 - val_loss: 0.0517
# Epoch 14/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0321 - val_loss: 0.0515
# Epoch 15/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0324 - val_loss: 0.0506
# Epoch 16/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0326 - val_loss: 0.0496
# Epoch 17/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0317 - val_loss: 0.0488
# Epoch 18/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0333 - val_loss: 0.0482
# Epoch 19/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0317 - val_loss: 0.0477
# Epoch 20/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0304 - val_loss: 0.0473
# Epoch 21/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0298 - val_loss: 0.0468
# Epoch 22/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0292 - val_loss: 0.0460
# Epoch 23/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0274 - val_loss: 0.0450
# Epoch 24/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0275 - val_loss: 0.0438
# Epoch 25/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0266 - val_loss: 0.0423
# Epoch 26/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0289 - val_loss: 0.0411
# Epoch 27/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0273 - val_loss: 0.0402
# Epoch 28/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0234 - val_loss: 0.0384
# Epoch 29/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0236 - val_loss: 0.0364
# Epoch 30/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0219 - val_loss: 0.0349
# Epoch 31/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0246 - val_loss: 0.0341
# Epoch 32/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0211 - val_loss: 0.0333
# Epoch 33/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0218 - val_loss: 0.0315
# Epoch 34/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0212 - val_loss: 0.0308
# Epoch 35/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0242 - val_loss: 0.0311
# Epoch 36/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0199 - val_loss: 0.0303
# Epoch 37/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0213 - val_loss: 0.0291
# Epoch 38/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0217 - val_loss: 0.0284
# Epoch 39/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0256 - val_loss: 0.0293
# Epoch 40/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0227 - val_loss: 0.0298
# Epoch 41/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0226 - val_loss: 0.0296
# Epoch 42/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0205 - val_loss: 0.0285
# Epoch 43/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0171 - val_loss: 0.0277
# Epoch 44/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0187 - val_loss: 0.0267
# Epoch 45/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0218 - val_loss: 0.0266
# Epoch 46/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0194 - val_loss: 0.0279
# Epoch 47/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0178 - val_loss: 0.0270
# Epoch 48/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0180 - val_loss: 0.0258
# Epoch 49/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0216 - val_loss: 0.0261
# Epoch 50/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0204 - val_loss: 0.0271
# Epoch 51/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0215 - val_loss: 0.0271
# Epoch 52/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0215 - val_loss: 0.0272
# Epoch 53/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0168 - val_loss: 0.0260
# Epoch 54/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0187 - val_loss: 0.0257
# Epoch 55/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0199 - val_loss: 0.0263
# Epoch 56/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0165 - val_loss: 0.0254
# Epoch 57/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0247
# Epoch 58/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0174 - val_loss: 0.0246
# Epoch 59/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0165 - val_loss: 0.0244
# Epoch 60/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0241
# Epoch 61/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0186 - val_loss: 0.0236
# Epoch 62/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0155 - val_loss: 0.0236
# Epoch 63/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0176 - val_loss: 0.0243
# Epoch 64/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0200 - val_loss: 0.0258
# Epoch 65/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0191 - val_loss: 0.0262
# Epoch 66/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0193 - val_loss: 0.0251
# Epoch 67/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0180 - val_loss: 0.0245
# Epoch 68/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0184 - val_loss: 0.0246
# Epoch 69/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0179 - val_loss: 0.0249
# Epoch 70/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0217 - val_loss: 0.0256
# Epoch 71/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0259
# Epoch 72/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0207 - val_loss: 0.0264
# Epoch 73/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0185 - val_loss: 0.0263
# Epoch 74/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0170 - val_loss: 0.0253
# Epoch 75/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0192 - val_loss: 0.0244
# Epoch 76/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0241
# Epoch 77/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0166 - val_loss: 0.0245
# Epoch 78/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0181 - val_loss: 0.0249
# Epoch 79/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0185 - val_loss: 0.0247
# Epoch 80/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0178 - val_loss: 0.0242
# Epoch 81/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0238
# Epoch 82/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0167 - val_loss: 0.0236
# Epoch 83/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0207 - val_loss: 0.0250
# Epoch 84/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0185 - val_loss: 0.0258
# Epoch 85/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0186 - val_loss: 0.0265
# Epoch 86/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0204 - val_loss: 0.0267
# Epoch 87/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0182 - val_loss: 0.0256
# Epoch 88/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0178 - val_loss: 0.0245
# Epoch 89/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0183 - val_loss: 0.0240
# Epoch 90/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0211 - val_loss: 0.0247
# Epoch 91/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0191 - val_loss: 0.0249
# Epoch 92/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0184 - val_loss: 0.0248
# Epoch 93/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0161 - val_loss: 0.0248
# Epoch 94/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0194 - val_loss: 0.0246
# Epoch 95/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0171 - val_loss: 0.0248
# Epoch 96/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0245
# Epoch 97/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0187 - val_loss: 0.0236
# Epoch 98/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0182 - val_loss: 0.0230
# Epoch 99/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0176 - val_loss: 0.0225
# Epoch 100/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0227
# Epoch 101/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0160 - val_loss: 0.0233
# Epoch 102/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0176 - val_loss: 0.0231
# Epoch 103/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0148 - val_loss: 0.0227
# Epoch 104/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0178 - val_loss: 0.0224
# Epoch 105/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0145 - val_loss: 0.0222
# Epoch 106/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0219
# Epoch 107/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0182 - val_loss: 0.0228
# Epoch 108/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0166 - val_loss: 0.0237
# Epoch 109/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0158 - val_loss: 0.0233
# Epoch 110/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0147 - val_loss: 0.0225
# Epoch 111/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0160 - val_loss: 0.0222
# Epoch 112/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0155 - val_loss: 0.0226
# Epoch 113/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0168 - val_loss: 0.0230
# Epoch 114/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0223
# Epoch 115/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0177 - val_loss: 0.0215
# Epoch 116/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0184 - val_loss: 0.0219
# Epoch 117/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0227
# Epoch 118/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0190 - val_loss: 0.0228
# Epoch 119/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0168 - val_loss: 0.0225
# Epoch 120/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0198 - val_loss: 0.0228
# Epoch 121/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0151 - val_loss: 0.0234
# Epoch 122/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0181 - val_loss: 0.0249
# Epoch 123/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0180 - val_loss: 0.0251
# Epoch 124/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0181 - val_loss: 0.0230
# Epoch 125/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0206 - val_loss: 0.0227
# Epoch 126/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.0234
# Epoch 127/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0152 - val_loss: 0.0242
# Epoch 128/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0176 - val_loss: 0.0233
# Epoch 129/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0157 - val_loss: 0.0229
# Epoch 130/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0225
# Epoch 131/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0131 - val_loss: 0.0223
# Epoch 132/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0167 - val_loss: 0.0224
# Epoch 133/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0156 - val_loss: 0.0226
# Epoch 134/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0202 - val_loss: 0.0227
# Epoch 135/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0184 - val_loss: 0.0223
# Epoch 136/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0144 - val_loss: 0.0222
# Epoch 137/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0187 - val_loss: 0.0225
# Epoch 138/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0154 - val_loss: 0.0225
# Epoch 139/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.0227
# Epoch 140/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0153 - val_loss: 0.0225
# Epoch 141/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0215
# Epoch 142/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0150 - val_loss: 0.0211
# Epoch 143/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0188 - val_loss: 0.0216
# Epoch 144/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0152 - val_loss: 0.0232
# Epoch 145/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0155 - val_loss: 0.0233
# Epoch 146/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0162 - val_loss: 0.0222
# Epoch 147/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0147 - val_loss: 0.0214
# Epoch 148/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0205 - val_loss: 0.0217
# Epoch 149/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0191 - val_loss: 0.0221
# Epoch 150/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0166 - val_loss: 0.0225

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history_bp.history['loss'], label='train')
plt.plot(history_bp.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make predictions
trainPredict_tm = regressorBilstm.predict(X_train_tm)
testPredict_tm = regressorBilstm.predict(X_test_tm)

# %%
plt.title('Train Dataset - Predicted v/s Actual')
plt.plot(trainPredict_tm , label='Predicted')
plt.plot(y_train_tm, label='Actual')
plt.legend()
plt.show()

# %%
plt.title('Test Dataset - Predicted v/s Actual')
plt.plot(testPredict_tm , label='Predicted')
plt.plot(y_test_tm, label='Actual')
plt.legend()
plt.show()

# %%
#Mean Absolute Error
mae_train_tm = mean_absolute_error(y_train_tm, trainPredict_tm)
mae_test_tm = mean_absolute_error(y_test_tm, testPredict_tm)
print('MAE Train: %.3f'% (mae_train_tm))
print('MAE Test: %.3f'% (mae_test_tm))
#Root Mean Squared Error
rmse_train_tm = mean_squared_error(y_train_tm, trainPredict_tm, squared=False)
rmse_test_tm = mean_squared_error(y_test_tm, testPredict_tm, squared=False)
print('RMSE Train: %.3f'% (rmse_train_tm))
print('RMSE Test: %.3f'% (rmse_test_tm))
#Mean Absolute Percentage Error
mp_train = mean_absolute_percentage_error(trainPredict,y_train)
mp_test = mean_absolute_percentage_error(testPredict,y_test)
print('MAPE Train: %.3f'% (mp_train))
print('MAPE Test: %.3f'% (mp_test))
# Out:
# MAE Train: 0.168
# MAE Test: 0.180
# RMSE Train: 0.221
# RMSE Test: 0.240
# MAPE Train: 0.299
# MAPE Test: 0.365
