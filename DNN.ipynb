# %% [markdown]
# **Recurrent Neural Networks**
#
# **Problem Statement:** Predicting spice crop yield from different parameters. The end result is a model that predicts yield for spice crops such as black pepper,dry ginger and turmeric.

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from keras.optimizers import adam_v2
from keras.layers import Dense, BatchNormalization, Dropout, LSTM,GRU,SimpleRNN
from keras.optimizers import adam_v2
from sklearn.model_selection import train_test_split
import sklearn.preprocessing as pre
from keras.models import Sequential
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
def mean_absolute_percentage_error(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual))

# %% [markdown]
# ## BLACK PEPPER

# %%
# importing data
data_bp = pd.read_csv("/content/black pepper 2008-2020.csv")
data_bp.head()
# Out:
#     DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED   pH  YIELD
# 0  Alappuzha  2008  2028  ...               8.29  6.6   0.13
# 1  Alappuzha  2009  1943  ...               8.52  6.2   0.12
# 2  Alappuzha  2010  2134  ...               7.88  6.0   0.14
# 3  Alappuzha  2011  1940  ...               7.89  5.9   0.09
# 4  Alappuzha  2012  1997  ...               8.19  6.0   0.08
#
# [5 rows x 12 columns]

# %%
data_bp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DISTRICT                169 non-null    object
#  1   YEAR                    169 non-null    int64
#  2   AREA                    169 non-null    int64
#  3   PRODUCTION              169 non-null    int64
#  4   AVERAGE RAINFALL        169 non-null    float64
#  5   MINIMUM TEMPERATURE     169 non-null    float64
#  6   MAXIMUM TEMPERATURE     169 non-null    float64
#  7   AVERAGE TEMPERATURE     169 non-null    float64
#  8   RELATIVE SOIL MOISTURE  169 non-null    float64
#  9   AVERAGE WINDSPEED       169 non-null    float64
#  10  pH                      169 non-null    float64
#  11  YIELD                   169 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 16.0+ KB

# %%
num_df_bp=data_bp.select_dtypes(include=["float64","int64"])
sns.heatmap(num_df_bp.corr(), cmap="YlGnBu", annot=True)
plt.rcParams["figure.figsize"] = [10,10]

# %%
le=pre.LabelEncoder()
cat_df_bp=data_bp.select_dtypes(exclude=[float,int])
for x in cat_df_bp.columns:
    data_bp[x]=le.fit_transform(data_bp[x])
X=data_bp.drop(['YIELD'], axis=1)
Y=data_bp["YIELD"]
X
# Out:
#      DISTRICT  YEAR   AREA  ...  RELATIVE SOIL MOISTURE  AVERAGE WINDSPEED   pH
# 0           0  2008   2028  ...                   0.184               8.29  6.6
# 1           0  2009   1943  ...                   0.106               8.52  6.2
# 2           0  2010   2134  ...                   0.330               7.88  6.0
# 3           0  2011   1940  ...                   0.112               7.89  5.9
# 4           0  2012   1997  ...                   0.106               8.19  6.0
# ..        ...   ...    ...  ...                     ...                ...  ...
# 164        12  2016  25542  ...                   0.436               7.67  6.2
# 165        12  2017  20825  ...                   0.429               9.51  6.4
# 166        12  2018  16571  ...                   0.422               9.79  5.5
# 167        12  2019  16189  ...                   0.217               9.01  5.4
# 168        12  2020   8422  ...                   0.403               9.46  5.6
#
# [169 rows x 11 columns]

# %%
df_list = data_bp.columns

# %%
sc = MinMaxScaler()
data_bp[df_list] = sc.fit_transform(data_bp[df_list])
data_bp
# Out:
#      DISTRICT      YEAR      AREA  ...  AVERAGE WINDSPEED        pH     YIELD
# 0         0.0  0.000000  0.015055  ...           0.461735  1.000000  0.092593
# 1         0.0  0.083333  0.014073  ...           0.491071  0.666667  0.074074
# 2         0.0  0.166667  0.016280  ...           0.409439  0.500000  0.111111
# 3         0.0  0.250000  0.014038  ...           0.410714  0.416667  0.018519
# 4         0.0  0.333333  0.014697  ...           0.448980  0.500000  0.000000
# ..        ...       ...       ...  ...                ...       ...       ...
# 164       1.0  0.666667  0.286739  ...           0.382653  0.666667  0.148148
# 165       1.0  0.750000  0.232238  ...           0.617347  0.833333  0.259259
# 166       1.0  0.833333  0.183087  ...           0.653061  0.083333  0.351852
# 167       1.0  0.916667  0.178673  ...           0.553571  0.000000  0.129630
# 168       1.0  1.000000  0.088932  ...           0.610969  0.166667  0.444444
#
# [169 rows x 12 columns]

# %%
X=data_bp.drop(['YIELD'], axis=1)
Y=data_bp["YIELD"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,train_size=0.7,random_state=12345)

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (118, 1, 11) (118,) (51, 1, 11) (51,)

# %% [markdown]
# # Defining a model

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_shape = (X_train.shape[1], X_train.shape[2]), activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(optimizer = 'adam', loss = 'mean_squared_error')
NN_model.summary()
history=NN_model.fit(X_train, y_train,validation_data=(X_test, y_test),epochs=150,shuffle=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1, 128)            1536
#
#  dense_1 (Dense)             (None, 1, 256)            33024
#
#  dense_2 (Dense)             (None, 1, 256)            65792
#
#  dense_3 (Dense)             (None, 1, 256)            65792
#
#  dense_4 (Dense)             (None, 1, 1)              257
#
# =================================================================
# Total params: 166,401
# Trainable params: 166,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 4/4 [==============================] - 1s 94ms/step - loss: 0.0991 - val_loss: 0.0287
# Epoch 2/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0512 - val_loss: 0.0577
# Epoch 3/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0511 - val_loss: 0.0265
# Epoch 4/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0475 - val_loss: 0.0251
# Epoch 5/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0468 - val_loss: 0.0281
# Epoch 6/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0444 - val_loss: 0.0369
# Epoch 7/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0454 - val_loss: 0.0307
# Epoch 8/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0444 - val_loss: 0.0268
# Epoch 9/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0445 - val_loss: 0.0279
# Epoch 10/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0439 - val_loss: 0.0318
# Epoch 11/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0441 - val_loss: 0.0309
# Epoch 12/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0440 - val_loss: 0.0284
# Epoch 13/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0439 - val_loss: 0.0287
# Epoch 14/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0438 - val_loss: 0.0305
# Epoch 15/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0438 - val_loss: 0.0300
# Epoch 16/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0438 - val_loss: 0.0289
# Epoch 17/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0438 - val_loss: 0.0294
# Epoch 18/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0437 - val_loss: 0.0300
# Epoch 19/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0438 - val_loss: 0.0295
# Epoch 20/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0437 - val_loss: 0.0292
# Epoch 21/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0437 - val_loss: 0.0296
# Epoch 22/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0437 - val_loss: 0.0296
# Epoch 23/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0437 - val_loss: 0.0293
# Epoch 24/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0437 - val_loss: 0.0295
# Epoch 25/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0437 - val_loss: 0.0296
# Epoch 26/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0437 - val_loss: 0.0294
# Epoch 27/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0437 - val_loss: 0.0294
# Epoch 28/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0437 - val_loss: 0.0295
# Epoch 29/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0437 - val_loss: 0.0294
# Epoch 30/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 31/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0436 - val_loss: 0.0295
# Epoch 32/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 33/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 34/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 35/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 36/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 37/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 38/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 39/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 40/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 41/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 42/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 43/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 44/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 45/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0436 - val_loss: 0.0294
# Epoch 46/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 47/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 48/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 49/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 50/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 51/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 52/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 54/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 55/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 56/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 57/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 58/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 59/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 60/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 62/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 63/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 64/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 65/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0435 - val_loss: 0.0293
# Epoch 66/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 67/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 68/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 69/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0435 - val_loss: 0.0294
# Epoch 70/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 71/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 72/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 73/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 74/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 75/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 76/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 77/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 78/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 79/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 80/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 81/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 82/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 83/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 84/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 85/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 86/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 87/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 88/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 89/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 90/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 91/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 92/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 93/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 94/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 95/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 96/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 97/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 98/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0292
# Epoch 99/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 100/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 101/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 102/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 103/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 104/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 105/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0434 - val_loss: 0.0292
# Epoch 106/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 107/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 108/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0291
# Epoch 109/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0293
# Epoch 110/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0292
# Epoch 112/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0433 - val_loss: 0.0290
# Epoch 113/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0293
# Epoch 114/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0296
# Epoch 115/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0292
# Epoch 116/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0287
# Epoch 117/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0294
# Epoch 118/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0298
# Epoch 119/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0289
# Epoch 120/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0286
# Epoch 121/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0434 - val_loss: 0.0301
# Epoch 122/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0292
# Epoch 123/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0282
# Epoch 124/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0299
# Epoch 125/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0434 - val_loss: 0.0293
# Epoch 126/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0283
# Epoch 127/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0434 - val_loss: 0.0301
# Epoch 128/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0290
# Epoch 129/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0285
# Epoch 130/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0301
# Epoch 131/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0434 - val_loss: 0.0289
# Epoch 132/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0433 - val_loss: 0.0288
# Epoch 133/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0297
# Epoch 134/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0434 - val_loss: 0.0288
# Epoch 135/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0290
# Epoch 136/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0295
# Epoch 137/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0288
# Epoch 138/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0433 - val_loss: 0.0290
# Epoch 139/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 140/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0433 - val_loss: 0.0289
# Epoch 141/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0433 - val_loss: 0.0290
# Epoch 142/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 143/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0289
# Epoch 144/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0433 - val_loss: 0.0289
# Epoch 145/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 146/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0290
# Epoch 147/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0287
# Epoch 148/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0294
# Epoch 149/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0433 - val_loss: 0.0292
# Epoch 150/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0433 - val_loss: 0.0287

# %% [markdown]
# ## MODEL EVALUATION

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
# make predictions
trainPredict = NN_model.predict(X_train)
testPredict = NN_model.predict(X_test)
trainPredict=np.reshape(trainPredict, (118, 1))
testPredict=np.reshape(testPredict, (51, 1))

# %%
plt.title('Train Dataset - Predicted v/s Actual')
plt.plot(trainPredict , label='Predicted')
plt.plot(y_train, label='Actual')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
plt.title('Test Dataset - Predicted v/s Actual')
plt.plot(testPredict , label='Predicted')
plt.plot(y_test, label='Actual')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
#Mean Absolute Error
mae_train = mean_absolute_error(y_train, trainPredict)
mae_test = mean_absolute_error(y_test, testPredict)
print('MAE Train: %.3f'% (mae_train))
print('MAE Test: %.3f'% (mae_test))
#Root Mean Squared Error
rmse_train = mean_squared_error(y_train, trainPredict, squared=False)
rmse_test = mean_squared_error(y_test, testPredict, squared=False)
print('RMSE Train: %.3f'% (rmse_train))
print('RMSE Test: %.3f'% (rmse_test))
#Mean Absolute Percentage Error
mp_train = mean_absolute_percentage_error(trainPredict,y_train)
mp_test = mean_absolute_percentage_error(testPredict,y_test)
print('MAPE Train: %.3f'% (mp_train))
print('MAPE Test: %.3f'% (mp_test))
# Out:
# MAE Train: 0.163
# MAE Test: 0.144
# RMSE Train: 0.208
# RMSE Test: 0.169
# MAPE Train: 0.598
# MAPE Test: 0.528

# %% [markdown]
# ## DRY GINGER

# %%
# importing data
data_dg = pd.read_csv("/content/dry ginger 2008-2020.csv")
data_dg.head()
# Out:
#     DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED    pH  YIELD
# 0  Alappuzha  2008   161  ...               8.29  6.27   2.19
# 1  Alappuzha  2009    66  ...               8.52  6.07   2.47
# 2  Alappuzha  2010    87  ...               7.88  5.62   3.02
# 3  Alappuzha  2011    94  ...               7.89  5.56   1.83
# 4  Alappuzha  2012   125  ...               8.19  6.04   1.76
#
# [5 rows x 12 columns]

# %%
data_dg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DISTRICT                181 non-null    object
#  1   YEAR                    181 non-null    int64
#  2   AREA                    181 non-null    int64
#  3   PRODUCTION              181 non-null    int64
#  4   AVERAGE RAINFALL        181 non-null    float64
#  5   MINIMUM TEMPERATURE     181 non-null    float64
#  6   MAXIMUM TEMPERATURE     181 non-null    float64
#  7   AVERAGE TEMPERATURE     181 non-null    float64
#  8   RELATIVE SOIL MOISTURE  181 non-null    float64
#  9   AVERAGE WINDSPEED       181 non-null    float64
#  10  pH                      181 non-null    float64
#  11  YIELD                   181 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 17.1+ KB

# %%
num_df_dg=data_dg.select_dtypes(include=["float64","int64"])
sns.heatmap(num_df_dg.corr(), cmap="YlGnBu", annot=True)
plt.rcParams["figure.figsize"] = [10,10]

# %%
le=pre.LabelEncoder()
cat_df_dg=data_dg.select_dtypes(exclude=[float,int])
for x in cat_df_dg.columns:
    data_dg[x]=le.fit_transform(data_dg[x])

# %%
df_list = data_dg.columns

# %%
sc = MinMaxScaler()
data_dg[df_list] = sc.fit_transform(data_dg[df_list])
data_dg
# Out:
#      DISTRICT      YEAR      AREA  ...  AVERAGE WINDSPEED    pH     YIELD
# 0    0.000000  0.000000  0.019857  ...           0.461735  0.72  0.109817
# 1    0.000000  0.083333  0.006757  ...           0.491071  0.52  0.156406
# 2    0.000000  0.166667  0.009653  ...           0.409439  0.07  0.247920
# 3    0.000000  0.250000  0.010618  ...           0.410714  0.01  0.049917
# 4    0.000000  0.333333  0.014892  ...           0.448980  0.49  0.038270
# ..        ...       ...       ...  ...                ...   ...       ...
# 176  0.307692  0.750000  0.000689  ...           0.608418  0.00  0.327787
# 177  0.307692  0.833333  0.003999  ...           0.698980  0.96  0.404326
# 178  0.307692  0.916667  0.016823  ...           0.661990  0.92  0.276206
# 179  0.307692  1.000000  0.011997  ...           0.656888  0.60  0.289517
# 180  0.307692  0.000000  0.005378  ...           0.600765  0.67  0.324459
#
# [181 rows x 12 columns]

# %%
X=data_dg.drop(['YIELD'], axis=1)
Y=data_dg["YIELD"]
X
# Out:
#      DISTRICT      YEAR  ...  AVERAGE WINDSPEED    pH
# 0    0.000000  0.000000  ...           0.461735  0.72
# 1    0.000000  0.083333  ...           0.491071  0.52
# 2    0.000000  0.166667  ...           0.409439  0.07
# 3    0.000000  0.250000  ...           0.410714  0.01
# 4    0.000000  0.333333  ...           0.448980  0.49
# ..        ...       ...  ...                ...   ...
# 176  0.307692  0.750000  ...           0.608418  0.00
# 177  0.307692  0.833333  ...           0.698980  0.96
# 178  0.307692  0.916667  ...           0.661990  0.92
# 179  0.307692  1.000000  ...           0.656888  0.60
# 180  0.307692  0.000000  ...           0.600765  0.67
#
# [181 rows x 11 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,train_size=0.7,random_state=12345)

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (126, 1, 11) (126,) (55, 1, 11) (55,)

# %% [markdown]
# # Defining a model

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_shape = (X_train.shape[1], X_train.shape[2]), activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(optimizer = 'adam', loss = 'mean_squared_error')
NN_model.summary()
history=NN_model.fit(X_train, y_train,validation_data=(X_test, y_test),epochs=100,shuffle=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 1, 128)            1536
#
#  dense_6 (Dense)             (None, 1, 256)            33024
#
#  dense_7 (Dense)             (None, 1, 256)            65792
#
#  dense_8 (Dense)             (None, 1, 256)            65792
#
#  dense_9 (Dense)             (None, 1, 1)              257
#
# =================================================================
# Total params: 166,401
# Trainable params: 166,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 4/4 [==============================] - 1s 82ms/step - loss: 0.0592 - val_loss: 0.0650
# Epoch 2/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0223 - val_loss: 0.0491
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0219 - val_loss: 0.0549
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0205 - val_loss: 0.0587
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0189 - val_loss: 0.0504
# Epoch 6/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0173 - val_loss: 0.0473
# Epoch 7/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0183 - val_loss: 0.0489
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0176 - val_loss: 0.0519
# Epoch 9/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0175 - val_loss: 0.0507
# Epoch 10/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0169 - val_loss: 0.0480
# Epoch 11/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0172 - val_loss: 0.0482
# Epoch 12/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0171 - val_loss: 0.0497
# Epoch 13/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0170 - val_loss: 0.0497
# Epoch 14/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0168 - val_loss: 0.0485
# Epoch 15/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0484
# Epoch 16/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0491
# Epoch 17/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0169 - val_loss: 0.0491
# Epoch 18/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0168 - val_loss: 0.0485
# Epoch 19/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0168 - val_loss: 0.0487
# Epoch 20/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0168 - val_loss: 0.0490
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0167 - val_loss: 0.0488
# Epoch 22/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0167 - val_loss: 0.0486
# Epoch 23/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0167 - val_loss: 0.0488
# Epoch 24/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0167 - val_loss: 0.0488
# Epoch 25/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0167 - val_loss: 0.0487
# Epoch 26/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0167 - val_loss: 0.0488
# Epoch 27/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0167 - val_loss: 0.0488
# Epoch 28/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0166 - val_loss: 0.0488
# Epoch 29/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0488
# Epoch 30/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 31/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0488
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 33/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 34/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 35/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 36/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 37/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0166 - val_loss: 0.0489
# Epoch 38/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0489
# Epoch 39/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0489
# Epoch 40/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0489
# Epoch 41/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0489
# Epoch 42/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 43/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 45/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0165 - val_loss: 0.0489
# Epoch 46/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 47/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 48/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 49/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 50/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 51/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 52/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 53/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0490
# Epoch 54/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 55/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 56/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 57/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 58/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 59/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0489
# Epoch 60/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0491
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0489
# Epoch 62/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0491
# Epoch 63/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 64/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0491
# Epoch 65/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 66/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0164 - val_loss: 0.0491
# Epoch 67/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0490
# Epoch 68/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0491
# Epoch 69/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 70/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 71/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 72/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 73/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 74/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 75/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 76/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 77/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 78/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0163 - val_loss: 0.0492
# Epoch 79/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 80/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0492
# Epoch 81/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0492
# Epoch 82/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.0491
# Epoch 83/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0163 - val_loss: 0.0492
# Epoch 84/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0492
# Epoch 85/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0492
# Epoch 86/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0163 - val_loss: 0.0493
# Epoch 87/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0492
# Epoch 88/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 89/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 90/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 91/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0162 - val_loss: 0.0494
# Epoch 92/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 93/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 94/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0162 - val_loss: 0.0495
# Epoch 95/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 96/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0162 - val_loss: 0.0494
# Epoch 97/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0495
# Epoch 98/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0162 - val_loss: 0.0494
# Epoch 99/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0493
# Epoch 100/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0495

# %% [markdown]
# ## MODEL EVALUATION

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
# make predictions
trainPredict = NN_model.predict(X_train)
testPredict = NN_model.predict(X_test)
trainPredict=np.reshape(trainPredict, (126, 1))
testPredict=np.reshape(testPredict, (55, 1))

# %%
plt.title('Train Dataset - Predicted v/s Actual')
plt.plot(trainPredict , label='Predicted')
plt.plot(y_train, label='Actual')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
plt.title('Test Dataset - Predicted v/s Actual')
plt.plot(testPredict , label='Predicted')
plt.plot(y_test, label='Actual')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
#Mean Absolute Error
mae_train = mean_absolute_error(y_train, trainPredict)
mae_test = mean_absolute_error(y_test, testPredict)
print('MAE Train: %.3f'% (mae_train))
print('MAE Test: %.3f'% (mae_test))
#Root Mean Squared Error
rmse_train = mean_squared_error(y_train, trainPredict, squared=False)
rmse_test = mean_squared_error(y_test, testPredict, squared=False)
print('RMSE Train: %.3f'% (rmse_train))
print('RMSE Test: %.3f'% (rmse_test))
#Mean Absolute Percentage Error
mp_train = mean_absolute_percentage_error(trainPredict,y_train)
mp_test = mean_absolute_percentage_error(testPredict,y_test)
print('MAPE Train: %.3f'% (mp_train))
print('MAPE Test: %.3f'% (mp_test))
# Out:
# MAE Train: 0.097
# MAE Test: 0.154
# RMSE Train: 0.126
# RMSE Test: 0.218
# MAPE Train: 0.385
# MAPE Test: 0.616

# %% [markdown]
# # TURMERIC

# %%
# importing data
data_tc = pd.read_csv("/content/turmeric 2008-2020.csv")
data_tc.head()
# Out:
#     DISTRICT  YEAR  AREA  ...  AVERAGE WINDSPEED    pH  YIELD
# 0  Alappuzha  2008    11  ...               8.29  6.28   1.18
# 1  Alappuzha  2009    20  ...               8.52  4.89   1.05
# 2  Alappuzha  2010    15  ...               7.88  5.38   1.33
# 3  Alappuzha  2011    12  ...               7.89  5.46   1.75
# 4  Alappuzha  2012    11  ...               8.19  5.64   1.09
#
# [5 rows x 12 columns]

# %%
data_tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DISTRICT                181 non-null    object
#  1   YEAR                    181 non-null    int64
#  2   AREA                    181 non-null    int64
#  3   PRODUCTION              181 non-null    int64
#  4   AVERAGE RAINFALL        181 non-null    float64
#  5   MINIMUM TEMPERATURE     181 non-null    float64
#  6   MAXIMUM TEMPERATURE     181 non-null    float64
#  7   AVERAGE TEMPERATURE     181 non-null    float64
#  8   RELATIVE SOIL MOISTURE  181 non-null    float64
#  9   AVERAGE WINDSPEED       181 non-null    float64
#  10  pH                      181 non-null    float64
#  11  YIELD                   181 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 17.1+ KB

# %%
num_df_tc=data_tc.select_dtypes(include=["float64","int64"])
sns.heatmap(num_df_tc.corr(), cmap="YlGnBu", annot=True)
plt.rcParams["figure.figsize"] = [10,10]

# %%
le=pre.LabelEncoder()
cat_df_tc=data_tc.select_dtypes(exclude=[float,int])
for x in cat_df_tc.columns:
    data_tc[x]=le.fit_transform(data_tc[x])
X=data_tc.drop(['YIELD'], axis=1)
Y=data_tc["YIELD"]

# %%
df_list = data_tc.columns

# %%
sc = MinMaxScaler()
data_tc[df_list] = sc.fit_transform(data_tc[df_list])
data_tc
# Out:
#      DISTRICT      YEAR      AREA  ...  AVERAGE WINDSPEED        pH     YIELD
# 0    0.000000  0.000000  0.003148  ...           0.461735  0.515254  0.106007
# 1    0.000000  0.083333  0.012592  ...           0.491071  0.044068  0.060071
# 2    0.000000  0.166667  0.007345  ...           0.409439  0.210169  0.159011
# 3    0.000000  0.250000  0.004197  ...           0.410714  0.237288  0.307420
# 4    0.000000  0.333333  0.003148  ...           0.448980  0.298305  0.074205
# ..        ...       ...       ...  ...                ...       ...       ...
# 176  0.307692  0.583333  0.069255  ...           0.589286  0.366102  0.395760
# 177  0.307692  0.750000  0.082896  ...           0.608418  0.481356  0.445230
# 178  0.307692  0.833333  0.012592  ...           0.480867  0.325424  0.547703
# 179  0.307692  0.916667  0.032529  ...           0.336735  0.105085  0.296820
# 180  0.307692  1.000000  0.014690  ...           0.246173  0.477966  0.395760
#
# [181 rows x 12 columns]

# %%
X=data_tc.drop(['YIELD'], axis=1)
Y=data_tc["YIELD"]
X
# Out:
#      DISTRICT      YEAR  ...  AVERAGE WINDSPEED        pH
# 0    0.000000  0.000000  ...           0.461735  0.515254
# 1    0.000000  0.083333  ...           0.491071  0.044068
# 2    0.000000  0.166667  ...           0.409439  0.210169
# 3    0.000000  0.250000  ...           0.410714  0.237288
# 4    0.000000  0.333333  ...           0.448980  0.298305
# ..        ...       ...  ...                ...       ...
# 176  0.307692  0.583333  ...           0.589286  0.366102
# 177  0.307692  0.750000  ...           0.608418  0.481356
# 178  0.307692  0.833333  ...           0.480867  0.325424
# 179  0.307692  0.916667  ...           0.336735  0.105085
# 180  0.307692  1.000000  ...           0.246173  0.477966
#
# [181 rows x 11 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,train_size=0.7,random_state=12345)

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_test, y_test = np.array(X_test), np.array(y_test)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (126, 1, 11) (126,) (55, 1, 11) (55,)

# %% [markdown]
# # Defining a model

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_shape = (X_train.shape[1], X_train.shape[2]), activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(optimizer = 'adam', loss = 'mean_squared_error')
NN_model.summary()
history=NN_model.fit(X_train, y_train,validation_data=(X_test, y_test),epochs=150,shuffle=False)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 1, 128)            1536
#
#  dense_16 (Dense)            (None, 1, 256)            33024
#
#  dense_17 (Dense)            (None, 1, 256)            65792
#
#  dense_18 (Dense)            (None, 1, 256)            65792
#
#  dense_19 (Dense)            (None, 1, 1)              257
#
# =================================================================
# Total params: 166,401
# Trainable params: 166,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 4/4 [==============================] - 1s 87ms/step - loss: 0.1845 - val_loss: 0.1115
# Epoch 2/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0714 - val_loss: 0.0660
# Epoch 3/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0610 - val_loss: 0.0487
# Epoch 4/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0493 - val_loss: 0.0624
# Epoch 5/150
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0536 - val_loss: 0.0536
# Epoch 6/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0475 - val_loss: 0.0472
# Epoch 7/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0481 - val_loss: 0.0470
# Epoch 8/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0457 - val_loss: 0.0492
# Epoch 9/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0462 - val_loss: 0.0505
# Epoch 10/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0460 - val_loss: 0.0474
# Epoch 11/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0453 - val_loss: 0.0465
# Epoch 12/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0451 - val_loss: 0.0471
# Epoch 13/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0448 - val_loss: 0.0482
# Epoch 14/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0449 - val_loss: 0.0473
# Epoch 15/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0447 - val_loss: 0.0466
# Epoch 16/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0445 - val_loss: 0.0468
# Epoch 17/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0444 - val_loss: 0.0473
# Epoch 18/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0444 - val_loss: 0.0470
# Epoch 19/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0443 - val_loss: 0.0466
# Epoch 20/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0441 - val_loss: 0.0468
# Epoch 21/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0441 - val_loss: 0.0469
# Epoch 22/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0440 - val_loss: 0.0467
# Epoch 23/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0440 - val_loss: 0.0466
# Epoch 24/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0439 - val_loss: 0.0467
# Epoch 25/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0438 - val_loss: 0.0467
# Epoch 26/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0438 - val_loss: 0.0466
# Epoch 27/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0437 - val_loss: 0.0466
# Epoch 28/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0437 - val_loss: 0.0466
# Epoch 29/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0436 - val_loss: 0.0466
# Epoch 30/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0436 - val_loss: 0.0466
# Epoch 31/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0435 - val_loss: 0.0466
# Epoch 32/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0435 - val_loss: 0.0466
# Epoch 33/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0434 - val_loss: 0.0466
# Epoch 34/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0434 - val_loss: 0.0465
# Epoch 35/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0434 - val_loss: 0.0465
# Epoch 36/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0433 - val_loss: 0.0465
# Epoch 37/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0433 - val_loss: 0.0465
# Epoch 38/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0433 - val_loss: 0.0465
# Epoch 39/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0432 - val_loss: 0.0465
# Epoch 40/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0432 - val_loss: 0.0465
# Epoch 41/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0432 - val_loss: 0.0465
# Epoch 42/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0431 - val_loss: 0.0465
# Epoch 43/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0431 - val_loss: 0.0465
# Epoch 44/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0431 - val_loss: 0.0465
# Epoch 45/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0431 - val_loss: 0.0465
# Epoch 46/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0430 - val_loss: 0.0465
# Epoch 47/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0430 - val_loss: 0.0465
# Epoch 48/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0430 - val_loss: 0.0465
# Epoch 49/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0430 - val_loss: 0.0465
# Epoch 50/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0429 - val_loss: 0.0465
# Epoch 51/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0429 - val_loss: 0.0465
# Epoch 52/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0429 - val_loss: 0.0465
# Epoch 53/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0429 - val_loss: 0.0465
# Epoch 54/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0429 - val_loss: 0.0465
# Epoch 55/150
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0429 - val_loss: 0.0465
# Epoch 56/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0428 - val_loss: 0.0465
# Epoch 57/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0428 - val_loss: 0.0465
# Epoch 58/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0428 - val_loss: 0.0465
# Epoch 59/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0428 - val_loss: 0.0465
# Epoch 60/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0428 - val_loss: 0.0465
# Epoch 61/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0428 - val_loss: 0.0466
# Epoch 62/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0427 - val_loss: 0.0466
# Epoch 63/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0427 - val_loss: 0.0466
# Epoch 64/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0427 - val_loss: 0.0466
# Epoch 65/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0427 - val_loss: 0.0466
# Epoch 66/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0427 - val_loss: 0.0466
# Epoch 67/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0427 - val_loss: 0.0466
# Epoch 68/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0426 - val_loss: 0.0466
# Epoch 69/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0426 - val_loss: 0.0466
# Epoch 70/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0426 - val_loss: 0.0466
# Epoch 71/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0426 - val_loss: 0.0467
# Epoch 72/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0426 - val_loss: 0.0467
# Epoch 73/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0426 - val_loss: 0.0467
# Epoch 74/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0426 - val_loss: 0.0467
# Epoch 75/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 76/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 77/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 78/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 79/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 80/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 81/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0425 - val_loss: 0.0467
# Epoch 82/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0424 - val_loss: 0.0468
# Epoch 83/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0424 - val_loss: 0.0467
# Epoch 84/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0424 - val_loss: 0.0468
# Epoch 85/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0424 - val_loss: 0.0468
# Epoch 86/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0424 - val_loss: 0.0468
# Epoch 87/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0424 - val_loss: 0.0468
# Epoch 88/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0424 - val_loss: 0.0468
# Epoch 89/150
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0423 - val_loss: 0.0468
# Epoch 90/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0423 - val_loss: 0.0468
# Epoch 91/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0423 - val_loss: 0.0469
# Epoch 92/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0423 - val_loss: 0.0468
# Epoch 93/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0423 - val_loss: 0.0469
# Epoch 94/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0423 - val_loss: 0.0469
# Epoch 95/150
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0423 - val_loss: 0.0468
# Epoch 96/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0423 - val_loss: 0.0469
# Epoch 97/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 98/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 99/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 100/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 101/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 102/150
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 103/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 104/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 105/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0422 - val_loss: 0.0470
# Epoch 106/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0422 - val_loss: 0.0469
# Epoch 107/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 108/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 109/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 110/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 111/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 112/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 113/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 114/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 115/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 116/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.0470
# Epoch 117/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 118/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 119/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 120/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 121/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 122/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0471
# Epoch 123/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0420 - val_loss: 0.0470
# Epoch 124/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.0471
# Epoch 125/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0471
# Epoch 126/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0471
# Epoch 127/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0471
# Epoch 128/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0420 - val_loss: 0.0471
# Epoch 129/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 130/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 131/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 132/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 133/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 134/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 135/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 136/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 137/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0419 - val_loss: 0.0472
# Epoch 138/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0419 - val_loss: 0.0472
# Epoch 139/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 140/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0419 - val_loss: 0.0472
# Epoch 141/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0419 - val_loss: 0.0472
# Epoch 142/150
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 143/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0418 - val_loss: 0.0472
# Epoch 144/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0418 - val_loss: 0.0472
# Epoch 145/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0418 - val_loss: 0.0471
# Epoch 146/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0418 - val_loss: 0.0472
# Epoch 147/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0418 - val_loss: 0.0472
# Epoch 148/150
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0418 - val_loss: 0.0472
# Epoch 149/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0418 - val_loss: 0.0472
# Epoch 150/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0418 - val_loss: 0.0472

# %% [markdown]
# ## MODEL EVALUATION

# %%
# plot loss during training
plt.title('Loss / Mean Squared Error')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.rcParams["figure.figsize"] = [8,8]
plt.legend()
plt.show()

# %%
# make predictions
trainPredict = NN_model.predict(X_train)
testPredict = NN_model.predict(X_test)
trainPredict=np.reshape(trainPredict, (126, 1))
testPredict=np.reshape(testPredict, (55, 1))

# %%
plt.title('Train Dataset - Predicted v/s Actual')
plt.plot(trainPredict , label='Predicted')
plt.plot(y_train, label='Actual')
plt.legend()
plt.show()

# %%
plt.title('Test Dataset - Predicted v/s Actual')
plt.plot(testPredict , label='Predicted')
plt.plot(y_test, label='Actual')
plt.legend()
plt.show()

# %%
#Mean Absolute Error
mae_train = mean_absolute_error(y_train, trainPredict)
mae_test = mean_absolute_error(y_test, testPredict)
print('MAE Train: %.3f'% (mae_train))
print('MAE Test: %.3f'% (mae_test))
#Root Mean Squared Error
rmse_train = mean_squared_error(y_train, trainPredict, squared=False)
rmse_test = mean_squared_error(y_test, testPredict, squared=False)
print('RMSE Train: %.3f'% (rmse_train))
print('RMSE Test: %.3f'% (rmse_test))
#Mean Absolute Percentage Error
mp_train = mean_absolute_percentage_error(trainPredict,y_train)
mp_test = mean_absolute_percentage_error(testPredict,y_test)
print('MAPE Train: %.3f'% (mp_train))
print('MAPE Test: %.3f'% (mp_test))
# Out:
# MAE Train: 0.164
# MAE Test: 0.175
# RMSE Train: 0.202
# RMSE Test: 0.216
# MAPE Train: 0.388
# MAPE Test: 0.401
